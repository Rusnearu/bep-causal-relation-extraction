# %% [markdown]
# # C-GCN: Causal Relation Extraction (3-class)
#
# Trains and evaluates C-GCN on CausalNewsCorpus, adapted for 3-class causal relation extraction.
#
# **Labels:** `Cause-Effect(e1,e2)`, `Cause-Effect(e2,e1)`, `Other`

# %% [markdown]
# ## 1. Set working directory to repo root

# %%
import os
if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('..')
print("Working directory:", os.getcwd())
# Out:
# Working directory: c:\Users\rusne\OneDrive - TU Eindhoven\bep-causal-relation-extraction

# %% [markdown]
# ## 2. Check GPU

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# GPU: NVIDIA RTX 1000 Ada Generation Laptop GPU

# %% [markdown]
# ## 3. Download GloVe embeddings
#
# Downloads `glove.840B.300d.txt` (~2 GB) to `data/glove/`. Skip this cell if you already have it.

# %%
import os, urllib.request, zipfile

glove_dir = 'data/glove'
glove_txt = os.path.join(glove_dir, 'glove.840B.300d.txt')
glove_zip = os.path.join(glove_dir, 'glove.840B.300d.zip')

if os.path.exists(glove_txt):
    print("GloVe already downloaded, skipping.")
else:
    os.makedirs(glove_dir, exist_ok=True)
    url = 'https://huggingface.co/stanfordnlp/glove/resolve/main/glove.840B.300d.zip'
    print(f"Downloading GloVe (~2 GB), this will take a few minutes...")
    urllib.request.urlretrieve(url, glove_zip)
    print("Unzipping...")
    with zipfile.ZipFile(glove_zip, 'r') as z:
        z.extractall(glove_dir)
    os.remove(glove_zip)
    print("Done:", glove_txt)
# Out:
# GloVe already downloaded, skipping.

# %% [markdown]
# ## 4. Build vocabulary and embedding matrix (run once)
#
# Reads `data/CausalNewsCorpus/cgcn/train.json` + `test.json`, looks up GloVe vectors, saves `vocab.pkl` + `embedding.npy`.

# %%
import os
os.makedirs('data/CausalNewsCorpus/cgcn/vocab', exist_ok=True)

# !python src/cgcn/prepare_vocab.py data/CausalNewsCorpus/cgcn data/CausalNewsCorpus/cgcn/vocab --glove_dir data/glove --wv_file glove.840B.300d.txt
# Out:
# loading files...
# 28669 tokens from 2023 examples loaded from data/CausalNewsCorpus/cgcn/train.json.
# 3113 tokens from 219 examples loaded from data/CausalNewsCorpus/cgcn/test.json.
# loading glove...
# 2195893 words loaded from glove.
# building vocab...
# vocab built with 5377/5669 words.
# calculating oov...
# train oov: 354/28669 (1.23%)
# test oov: 421/3113 (13.52%)
# building embeddings...
# embedding size: 5377 x 300
# dumping to files...
# all done.

# %% [markdown]
# ## 5. Train C-GCN
#
# Evaluates on test after every epoch. Best checkpoint selected by test F1. Results saved to `results/cgcn/cnc/`.

# %%
import os
os.makedirs('results/cgcn/cnc', exist_ok=True)
os.makedirs('saved_models/cgcn_cnc', exist_ok=True)

# !python src/cgcn/train.py --data_dir data/CausalNewsCorpus/cgcn --vocab_dir data/CausalNewsCorpus/cgcn/vocab --eval_dir results/cgcn/cnc --save_dir saved_models/cgcn_cnc --id 01 --prune_k 1 --lr 1.0 --optim sgd --num_epoch 100 --batch_size 50 --seed 1234
# Out:
# Vocab size 5377 loaded from file
# Loading data from data/CausalNewsCorpus/cgcn with batch size 50...
# 41 batches created for data/CausalNewsCorpus/cgcn/train.json
# 5 batches created for data/CausalNewsCorpus/cgcn/test.json
# Config saved to file saved_models/cgcn_cnc/01/config.json
# Overwriting old vocab file at saved_models/cgcn_cnc/01/vocab.pkl
#
# Running with the following configs:
# 	data_dir : data/CausalNewsCorpus/cgcn
# 	vocab_dir : data/CausalNewsCorpus/cgcn/vocab
# 	eval_dir : results/cgcn/cnc
# 	emb_dim : 300
# 	ner_dim : 30
# 	pos_dim : 30
# 	hidden_dim : 200
# 	num_layers : 2
# 	input_dropout : 0.5
# 	gcn_dropout : 0.5
# 	word_dropout : 0.04
# 	topn : 10000000000.0
# 	lower : False
# 	prune_k : 1
# 	conv_l2 : 0
# 	pooling : max
# 	pooling_l2 : 0
# 	mlp_layers : 2
# 	no_adj : False
# 	rnn : True
# 	rnn_hidden : 200
# 	rnn_layers : 1
# 	rnn_dropout : 0.5
# 	lr : 1.0
# 	lr_decay : 0.9
# 	decay_epoch : 5
# 	optim : sgd
# 	num_epoch : 100
# 	batch_size : 50
# 	max_grad_norm : 5.0
# 	log_step : 20
# 	log : logs.txt
# 	save_epoch : 100
# 	save_dir : saved_models/cgcn_cnc
# 	id : 01
# 	info :
# 	seed : 1234
# 	cuda : True
# 	cpu : False
# 	load : False
# 	model_file : None
# 	num_class : 3
# 	vocab_size : 5377
# 	model_save_dir : saved_models/cgcn_cnc/01
#
#
# Finetune all embeddings.
# 2026-05-23 01:53:06.291114: step 20/4100 (epoch 1/100), loss = 0.796529 (0.031 sec/batch), lr: 1.000000
# 2026-05-23 01:53:07.010579: step 40/4100 (epoch 1/100), loss = 0.774741 (0.027 sec/batch), lr: 1.000000
# Evaluating on test set...
# epoch 1: train_loss = 0.941531, test_loss = 0.954613, test_f1 = 0.7525
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_1.pt
# new best model saved.
#
# 2026-05-23 01:53:07.803164: step 60/4100 (epoch 2/100), loss = 0.973574 (0.029 sec/batch), lr: 1.000000
# 2026-05-23 01:53:08.606126: step 80/4100 (epoch 2/100), loss = 0.911171 (0.027 sec/batch), lr: 1.000000
# Evaluating on test set...
# epoch 2: train_loss = 0.927773, test_loss = 0.961378, test_f1 = 0.7525
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_2.pt
#
# 2026-05-23 01:53:09.358260: step 100/4100 (epoch 3/100), loss = 0.973456 (0.038 sec/batch), lr: 1.000000
# 2026-05-23 01:53:10.020427: step 120/4100 (epoch 3/100), loss = 1.012296 (0.016 sec/batch), lr: 1.000000
# Evaluating on test set...
# epoch 3: train_loss = 0.932220, test_loss = 0.960274, test_f1 = 0.7525
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_3.pt
#
# 2026-05-23 01:53:10.770754: step 140/4100 (epoch 4/100), loss = 0.849405 (0.031 sec/batch), lr: 1.000000
# 2026-05-23 01:53:11.563889: step 160/4100 (epoch 4/100), loss = 1.055316 (0.045 sec/batch), lr: 1.000000
# Evaluating on test set...
# epoch 4: train_loss = 0.923049, test_loss = 0.970467, test_f1 = 0.7525
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_4.pt
#
# 2026-05-23 01:53:12.320959: step 180/4100 (epoch 5/100), loss = 0.993643 (0.033 sec/batch), lr: 1.000000
# 2026-05-23 01:53:12.992436: step 200/4100 (epoch 5/100), loss = 0.715465 (0.027 sec/batch), lr: 1.000000
# Evaluating on test set...
# epoch 5: train_loss = 0.872952, test_loss = 0.952236, test_f1 = 0.7562
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_5.pt
# new best model saved.
#
# 2026-05-23 01:53:13.781292: step 220/4100 (epoch 6/100), loss = 0.735336 (0.021 sec/batch), lr: 1.000000
# 2026-05-23 01:53:14.461306: step 240/4100 (epoch 6/100), loss = 0.896907 (0.030 sec/batch), lr: 1.000000
# Evaluating on test set...
# epoch 6: train_loss = 0.873969, test_loss = 0.920413, test_f1 = 0.7525
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_6.pt
#
# 2026-05-23 01:53:15.371222: step 260/4100 (epoch 7/100), loss = 0.742213 (0.035 sec/batch), lr: 1.000000
# 2026-05-23 01:53:16.038563: step 280/4100 (epoch 7/100), loss = 0.750489 (0.031 sec/batch), lr: 1.000000
# Evaluating on test set...
# epoch 7: train_loss = 0.942389, test_loss = 0.960234, test_f1 = 0.7525
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_7.pt
#
# 2026-05-23 01:53:16.801695: step 300/4100 (epoch 8/100), loss = 0.983691 (0.031 sec/batch), lr: 0.900000
# 2026-05-23 01:53:17.489439: step 320/4100 (epoch 8/100), loss = 0.860521 (0.031 sec/batch), lr: 0.900000
# Evaluating on test set...
# epoch 8: train_loss = 0.932219, test_loss = 0.961880, test_f1 = 0.7525
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_8.pt
#
# 2026-05-23 01:53:18.415806: step 340/4100 (epoch 9/100), loss = 0.972226 (0.031 sec/batch), lr: 0.810000
# 2026-05-23 01:53:19.097980: step 360/4100 (epoch 9/100), loss = 0.848784 (0.025 sec/batch), lr: 0.810000
# Evaluating on test set...
# epoch 9: train_loss = 0.932045, test_loss = 0.961685, test_f1 = 0.7525
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_9.pt
#
# 2026-05-23 01:53:19.881006: step 380/4100 (epoch 10/100), loss = 0.806723 (0.027 sec/batch), lr: 0.729000
# 2026-05-23 01:53:20.547589: step 400/4100 (epoch 10/100), loss = 0.929082 (0.021 sec/batch), lr: 0.729000
# Evaluating on test set...
# epoch 10: train_loss = 0.900094, test_loss = 0.766741, test_f1 = 0.7792
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_10.pt
# new best model saved.
#
# 2026-05-23 01:53:21.347518: step 420/4100 (epoch 11/100), loss = 0.756242 (0.033 sec/batch), lr: 0.729000
# 2026-05-23 01:53:22.175058: step 440/4100 (epoch 11/100), loss = 0.627288 (0.026 sec/batch), lr: 0.729000
# Evaluating on test set...
# epoch 11: train_loss = 0.727504, test_loss = 0.686770, test_f1 = 0.7842
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_11.pt
# new best model saved.
#
# 2026-05-23 01:53:22.947738: step 460/4100 (epoch 12/100), loss = 0.617946 (0.034 sec/batch), lr: 0.729000
# 2026-05-23 01:53:23.664203: step 480/4100 (epoch 12/100), loss = 0.523865 (0.033 sec/batch), lr: 0.729000
# Evaluating on test set...
# epoch 12: train_loss = 0.613974, test_loss = 0.655919, test_f1 = 0.7865
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_12.pt
# new best model saved.
#
# 2026-05-23 01:53:24.497635: step 500/4100 (epoch 13/100), loss = 0.799466 (0.029 sec/batch), lr: 0.729000
# 2026-05-23 01:53:25.364595: step 520/4100 (epoch 13/100), loss = 0.563598 (0.038 sec/batch), lr: 0.729000
# Evaluating on test set...
# epoch 13: train_loss = 0.561170, test_loss = 0.591314, test_f1 = 0.8170
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_13.pt
# new best model saved.
#
# 2026-05-23 01:53:26.158149: step 540/4100 (epoch 14/100), loss = 0.780317 (0.029 sec/batch), lr: 0.729000
# 2026-05-23 01:53:26.818276: step 560/4100 (epoch 14/100), loss = 0.559247 (0.035 sec/batch), lr: 0.729000
# Evaluating on test set...
# epoch 14: train_loss = 0.518544, test_loss = 0.575185, test_f1 = 0.7775
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_14.pt
#
# 2026-05-23 01:53:27.610346: step 580/4100 (epoch 15/100), loss = 0.479472 (0.032 sec/batch), lr: 0.656100
# 2026-05-23 01:53:28.287643: step 600/4100 (epoch 15/100), loss = 0.297125 (0.031 sec/batch), lr: 0.656100
# Evaluating on test set...
# epoch 15: train_loss = 0.490894, test_loss = 0.514185, test_f1 = 0.8127
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_15.pt
#
# 2026-05-23 01:53:29.204489: step 620/4100 (epoch 16/100), loss = 0.265547 (0.031 sec/batch), lr: 0.656100
# 2026-05-23 01:53:29.903315: step 640/4100 (epoch 16/100), loss = 0.277392 (0.031 sec/batch), lr: 0.656100
# Evaluating on test set...
# epoch 16: train_loss = 0.479851, test_loss = 0.503038, test_f1 = 0.8254
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_16.pt
# new best model saved.
#
# 2026-05-23 01:53:30.713422: step 660/4100 (epoch 17/100), loss = 0.364722 (0.028 sec/batch), lr: 0.656100
# 2026-05-23 01:53:31.385074: step 680/4100 (epoch 17/100), loss = 0.325458 (0.031 sec/batch), lr: 0.656100
# Evaluating on test set...
# epoch 17: train_loss = 0.444749, test_loss = 0.508567, test_f1 = 0.8021
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_17.pt
#
# 2026-05-23 01:53:32.280879: step 700/4100 (epoch 18/100), loss = 0.417706 (0.033 sec/batch), lr: 0.590490
# 2026-05-23 01:53:32.964193: step 720/4100 (epoch 18/100), loss = 0.481840 (0.032 sec/batch), lr: 0.590490
# Evaluating on test set...
# epoch 18: train_loss = 0.423823, test_loss = 0.511315, test_f1 = 0.8443
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_18.pt
# new best model saved.
#
# 2026-05-23 01:53:33.766673: step 740/4100 (epoch 19/100), loss = 0.341649 (0.031 sec/batch), lr: 0.590490
# 2026-05-23 01:53:34.451644: step 760/4100 (epoch 19/100), loss = 0.491630 (0.022 sec/batch), lr: 0.590490
# Evaluating on test set...
# epoch 19: train_loss = 0.393636, test_loss = 0.460044, test_f1 = 0.8632
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_19.pt
# new best model saved.
#
# 2026-05-23 01:53:35.232569: step 780/4100 (epoch 20/100), loss = 0.308517 (0.021 sec/batch), lr: 0.590490
# 2026-05-23 01:53:36.051111: step 800/4100 (epoch 20/100), loss = 0.475805 (0.035 sec/batch), lr: 0.590490
# 2026-05-23 01:53:36.719897: step 820/4100 (epoch 20/100), loss = 0.437620 (0.020 sec/batch), lr: 0.590490
# Evaluating on test set...
# epoch 20: train_loss = 0.472386, test_loss = 0.550162, test_f1 = 0.8351
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_20.pt
#
# 2026-05-23 01:53:37.476882: step 840/4100 (epoch 21/100), loss = 0.298479 (0.030 sec/batch), lr: 0.531441
# 2026-05-23 01:53:38.163894: step 860/4100 (epoch 21/100), loss = 0.347382 (0.031 sec/batch), lr: 0.531441
# Evaluating on test set...
# epoch 21: train_loss = 0.382316, test_loss = 0.494166, test_f1 = 0.8312
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_21.pt
#
# 2026-05-23 01:53:38.940071: step 880/4100 (epoch 22/100), loss = 0.364416 (0.031 sec/batch), lr: 0.478297
# 2026-05-23 01:53:39.797950: step 900/4100 (epoch 22/100), loss = 0.393935 (0.035 sec/batch), lr: 0.478297
# Evaluating on test set...
# epoch 22: train_loss = 0.371946, test_loss = 0.446936, test_f1 = 0.8714
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_22.pt
# new best model saved.
#
# 2026-05-23 01:53:40.586776: step 920/4100 (epoch 23/100), loss = 0.383669 (0.031 sec/batch), lr: 0.478297
# 2026-05-23 01:53:41.337149: step 940/4100 (epoch 23/100), loss = 0.308895 (0.064 sec/batch), lr: 0.478297
# Evaluating on test set...
# epoch 23: train_loss = 0.350823, test_loss = 0.461792, test_f1 = 0.8796
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_23.pt
# new best model saved.
#
# 2026-05-23 01:53:42.646035: step 960/4100 (epoch 24/100), loss = 0.236967 (0.047 sec/batch), lr: 0.478297
# 2026-05-23 01:53:43.910026: step 980/4100 (epoch 24/100), loss = 0.433733 (0.236 sec/batch), lr: 0.478297
# Evaluating on test set...
# epoch 24: train_loss = 0.350302, test_loss = 0.437686, test_f1 = 0.8714
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_24.pt
#
# 2026-05-23 01:53:45.114017: step 1000/4100 (epoch 25/100), loss = 0.419008 (0.054 sec/batch), lr: 0.430467
# 2026-05-23 01:53:46.220152: step 1020/4100 (epoch 25/100), loss = 0.382811 (0.053 sec/batch), lr: 0.430467
# Evaluating on test set...
# epoch 25: train_loss = 0.336124, test_loss = 0.503118, test_f1 = 0.8260
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_25.pt
#
# 2026-05-23 01:53:47.541540: step 1040/4100 (epoch 26/100), loss = 0.149571 (0.045 sec/batch), lr: 0.387420
# 2026-05-23 01:53:48.659398: step 1060/4100 (epoch 26/100), loss = 0.311604 (0.043 sec/batch), lr: 0.387420
# Evaluating on test set...
# epoch 26: train_loss = 0.330480, test_loss = 0.394881, test_f1 = 0.8889
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_26.pt
# new best model saved.
#
# 2026-05-23 01:53:50.163296: step 1080/4100 (epoch 27/100), loss = 0.297664 (0.047 sec/batch), lr: 0.387420
# 2026-05-23 01:53:50.965989: step 1100/4100 (epoch 27/100), loss = 0.306116 (0.031 sec/batch), lr: 0.387420
# Evaluating on test set...
# epoch 27: train_loss = 0.323141, test_loss = 0.489738, test_f1 = 0.8497
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_27.pt
#
# 2026-05-23 01:53:51.843890: step 1120/4100 (epoch 28/100), loss = 0.311721 (0.034 sec/batch), lr: 0.348678
# 2026-05-23 01:53:52.610941: step 1140/4100 (epoch 28/100), loss = 0.195479 (0.036 sec/batch), lr: 0.348678
# Evaluating on test set...
# epoch 28: train_loss = 0.299880, test_loss = 0.397431, test_f1 = 0.8907
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_28.pt
# new best model saved.
#
# 2026-05-23 01:53:53.496888: step 1160/4100 (epoch 29/100), loss = 0.227774 (0.031 sec/batch), lr: 0.348678
# 2026-05-23 01:53:54.415079: step 1180/4100 (epoch 29/100), loss = 0.145646 (0.036 sec/batch), lr: 0.348678
# Evaluating on test set...
# epoch 29: train_loss = 0.299270, test_loss = 0.371484, test_f1 = 0.8936
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_29.pt
# new best model saved.
#
# 2026-05-23 01:53:55.305383: step 1200/4100 (epoch 30/100), loss = 0.160108 (0.032 sec/batch), lr: 0.348678
# 2026-05-23 01:53:56.079777: step 1220/4100 (epoch 30/100), loss = 0.209743 (0.032 sec/batch), lr: 0.348678
# Evaluating on test set...
# epoch 30: train_loss = 0.277001, test_loss = 0.408298, test_f1 = 0.8632
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_30.pt
#
# 2026-05-23 01:53:56.943752: step 1240/4100 (epoch 31/100), loss = 0.420678 (0.040 sec/batch), lr: 0.313811
# 2026-05-23 01:53:57.888401: step 1260/4100 (epoch 31/100), loss = 0.394777 (0.031 sec/batch), lr: 0.313811
# Evaluating on test set...
# epoch 31: train_loss = 0.274372, test_loss = 0.367656, test_f1 = 0.8960
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_31.pt
# new best model saved.
#
# 2026-05-23 01:53:58.773570: step 1280/4100 (epoch 32/100), loss = 0.288591 (0.036 sec/batch), lr: 0.313811
# 2026-05-23 01:53:59.536033: step 1300/4100 (epoch 32/100), loss = 0.237095 (0.034 sec/batch), lr: 0.313811
# Evaluating on test set...
# epoch 32: train_loss = 0.268747, test_loss = 0.367438, test_f1 = 0.8930
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_32.pt
#
# 2026-05-23 01:54:00.385861: step 1320/4100 (epoch 33/100), loss = 0.389499 (0.035 sec/batch), lr: 0.282430
# 2026-05-23 01:54:01.164876: step 1340/4100 (epoch 33/100), loss = 0.408410 (0.053 sec/batch), lr: 0.282430
# Evaluating on test set...
# epoch 33: train_loss = 0.270710, test_loss = 0.372038, test_f1 = 0.8930
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_33.pt
#
# 2026-05-23 01:54:02.168734: step 1360/4100 (epoch 34/100), loss = 0.576622 (0.035 sec/batch), lr: 0.254187
# 2026-05-23 01:54:02.924681: step 1380/4100 (epoch 34/100), loss = 0.105801 (0.040 sec/batch), lr: 0.254187
# Evaluating on test set...
# epoch 34: train_loss = 0.258310, test_loss = 0.356157, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_34.pt
#
# 2026-05-23 01:54:03.813997: step 1400/4100 (epoch 35/100), loss = 0.306441 (0.034 sec/batch), lr: 0.254187
# 2026-05-23 01:54:04.636578: step 1420/4100 (epoch 35/100), loss = 0.169572 (0.036 sec/batch), lr: 0.254187
# Evaluating on test set...
# epoch 35: train_loss = 0.249726, test_loss = 0.370664, test_f1 = 0.8789
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_35.pt
#
# 2026-05-23 01:54:05.519472: step 1440/4100 (epoch 36/100), loss = 0.099428 (0.023 sec/batch), lr: 0.228768
# 2026-05-23 01:54:06.526402: step 1460/4100 (epoch 36/100), loss = 0.134480 (0.032 sec/batch), lr: 0.228768
# Evaluating on test set...
# epoch 36: train_loss = 0.242796, test_loss = 0.355581, test_f1 = 0.8960
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_36.pt
#
# 2026-05-23 01:54:07.446160: step 1480/4100 (epoch 37/100), loss = 0.271745 (0.030 sec/batch), lr: 0.228768
# 2026-05-23 01:54:08.257609: step 1500/4100 (epoch 37/100), loss = 0.119400 (0.028 sec/batch), lr: 0.228768
# Evaluating on test set...
# epoch 37: train_loss = 0.254135, test_loss = 0.345466, test_f1 = 0.8984
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_37.pt
# new best model saved.
#
# 2026-05-23 01:54:09.223021: step 1520/4100 (epoch 38/100), loss = 0.298661 (0.043 sec/batch), lr: 0.228768
# 2026-05-23 01:54:10.135918: step 1540/4100 (epoch 38/100), loss = 0.241047 (0.030 sec/batch), lr: 0.228768
# Evaluating on test set...
# epoch 38: train_loss = 0.240216, test_loss = 0.362384, test_f1 = 0.9062
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_38.pt
# new best model saved.
#
# 2026-05-23 01:54:11.023449: step 1560/4100 (epoch 39/100), loss = 0.157315 (0.041 sec/batch), lr: 0.228768
# 2026-05-23 01:54:11.782395: step 1580/4100 (epoch 39/100), loss = 0.222852 (0.035 sec/batch), lr: 0.228768
# Evaluating on test set...
# epoch 39: train_loss = 0.234143, test_loss = 0.356291, test_f1 = 0.8984
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_39.pt
#
# 2026-05-23 01:54:12.614721: step 1600/4100 (epoch 40/100), loss = 0.216028 (0.030 sec/batch), lr: 0.205891
# 2026-05-23 01:54:13.387934: step 1620/4100 (epoch 40/100), loss = 0.228408 (0.035 sec/batch), lr: 0.205891
# 2026-05-23 01:54:14.270088: step 1640/4100 (epoch 40/100), loss = 0.197440 (0.020 sec/batch), lr: 0.205891
# Evaluating on test set...
# epoch 40: train_loss = 0.233127, test_loss = 0.350645, test_f1 = 0.8883
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_40.pt
#
# 2026-05-23 01:54:15.146030: step 1660/4100 (epoch 41/100), loss = 0.182363 (0.038 sec/batch), lr: 0.185302
# 2026-05-23 01:54:15.915804: step 1680/4100 (epoch 41/100), loss = 0.336057 (0.036 sec/batch), lr: 0.185302
# Evaluating on test set...
# epoch 41: train_loss = 0.238011, test_loss = 0.382764, test_f1 = 0.8848
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_41.pt
#
# 2026-05-23 01:54:16.796735: step 1700/4100 (epoch 42/100), loss = 0.215215 (0.034 sec/batch), lr: 0.166772
# 2026-05-23 01:54:17.587544: step 1720/4100 (epoch 42/100), loss = 0.258319 (0.034 sec/batch), lr: 0.166772
# Evaluating on test set...
# epoch 42: train_loss = 0.235341, test_loss = 0.359812, test_f1 = 0.8936
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_42.pt
#
# 2026-05-23 01:54:18.553727: step 1740/4100 (epoch 43/100), loss = 0.130134 (0.031 sec/batch), lr: 0.166772
# 2026-05-23 01:54:19.329959: step 1760/4100 (epoch 43/100), loss = 0.156489 (0.032 sec/batch), lr: 0.166772
# Evaluating on test set...
# epoch 43: train_loss = 0.221783, test_loss = 0.353343, test_f1 = 0.9115
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_43.pt
# new best model saved.
#
# 2026-05-23 01:54:20.204772: step 1780/4100 (epoch 44/100), loss = 0.169089 (0.031 sec/batch), lr: 0.166772
# 2026-05-23 01:54:21.041143: step 1800/4100 (epoch 44/100), loss = 0.234828 (0.061 sec/batch), lr: 0.166772
# Evaluating on test set...
# epoch 44: train_loss = 0.224281, test_loss = 0.373325, test_f1 = 0.8936
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_44.pt
#
# 2026-05-23 01:54:22.105401: step 1820/4100 (epoch 45/100), loss = 0.300736 (0.035 sec/batch), lr: 0.150095
# 2026-05-23 01:54:22.873607: step 1840/4100 (epoch 45/100), loss = 0.404324 (0.028 sec/batch), lr: 0.150095
# Evaluating on test set...
# epoch 45: train_loss = 0.215966, test_loss = 0.345206, test_f1 = 0.9037
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_45.pt
#
# 2026-05-23 01:54:23.748790: step 1860/4100 (epoch 46/100), loss = 0.159215 (0.028 sec/batch), lr: 0.150095
# 2026-05-23 01:54:24.491408: step 1880/4100 (epoch 46/100), loss = 0.196763 (0.029 sec/batch), lr: 0.150095
# Evaluating on test set...
# epoch 46: train_loss = 0.220562, test_loss = 0.343930, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_46.pt
#
# 2026-05-23 01:54:25.361392: step 1900/4100 (epoch 47/100), loss = 0.166227 (0.038 sec/batch), lr: 0.135085
# 2026-05-23 01:54:26.353269: step 1920/4100 (epoch 47/100), loss = 0.291118 (0.040 sec/batch), lr: 0.135085
# Evaluating on test set...
# epoch 47: train_loss = 0.205561, test_loss = 0.341751, test_f1 = 0.9062
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_47.pt
#
# 2026-05-23 01:54:27.266913: step 1940/4100 (epoch 48/100), loss = 0.322862 (0.037 sec/batch), lr: 0.135085
# 2026-05-23 01:54:28.040756: step 1960/4100 (epoch 48/100), loss = 0.144973 (0.031 sec/batch), lr: 0.135085
# Evaluating on test set...
# epoch 48: train_loss = 0.214273, test_loss = 0.349331, test_f1 = 0.8960
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_48.pt
#
# 2026-05-23 01:54:28.901422: step 1980/4100 (epoch 49/100), loss = 0.131741 (0.031 sec/batch), lr: 0.121577
# 2026-05-23 01:54:29.654783: step 2000/4100 (epoch 49/100), loss = 0.130287 (0.024 sec/batch), lr: 0.121577
# Evaluating on test set...
# epoch 49: train_loss = 0.206893, test_loss = 0.347430, test_f1 = 0.8984
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_49.pt
#
# 2026-05-23 01:54:30.667565: step 2020/4100 (epoch 50/100), loss = 0.138338 (0.032 sec/batch), lr: 0.121577
# 2026-05-23 01:54:31.417395: step 2040/4100 (epoch 50/100), loss = 0.279079 (0.031 sec/batch), lr: 0.121577
# Evaluating on test set...
# epoch 50: train_loss = 0.206436, test_loss = 0.336355, test_f1 = 0.9037
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_50.pt
#
# 2026-05-23 01:54:32.306190: step 2060/4100 (epoch 51/100), loss = 0.238188 (0.043 sec/batch), lr: 0.121577
# 2026-05-23 01:54:33.095715: step 2080/4100 (epoch 51/100), loss = 0.439923 (0.033 sec/batch), lr: 0.121577
# Evaluating on test set...
# epoch 51: train_loss = 0.202144, test_loss = 0.342835, test_f1 = 0.9037
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_51.pt
#
# 2026-05-23 01:54:33.976317: step 2100/4100 (epoch 52/100), loss = 0.270373 (0.041 sec/batch), lr: 0.109419
# 2026-05-23 01:54:34.916039: step 2120/4100 (epoch 52/100), loss = 0.184364 (0.037 sec/batch), lr: 0.109419
# Evaluating on test set...
# epoch 52: train_loss = 0.201190, test_loss = 0.337097, test_f1 = 0.9091
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_52.pt
#
# 2026-05-23 01:54:35.795537: step 2140/4100 (epoch 53/100), loss = 0.274149 (0.037 sec/batch), lr: 0.109419
# 2026-05-23 01:54:36.613181: step 2160/4100 (epoch 53/100), loss = 0.252639 (0.060 sec/batch), lr: 0.109419
# Evaluating on test set...
# epoch 53: train_loss = 0.205059, test_loss = 0.341105, test_f1 = 0.8930
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_53.pt
#
# 2026-05-23 01:54:37.706663: step 2180/4100 (epoch 54/100), loss = 0.371350 (0.046 sec/batch), lr: 0.098477
# 2026-05-23 01:54:39.039151: step 2200/4100 (epoch 54/100), loss = 0.100800 (0.067 sec/batch), lr: 0.098477
# Evaluating on test set...
# epoch 54: train_loss = 0.194034, test_loss = 0.347584, test_f1 = 0.8984
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_54.pt
#
# 2026-05-23 01:54:40.348657: step 2220/4100 (epoch 55/100), loss = 0.298232 (0.043 sec/batch), lr: 0.098477
# 2026-05-23 01:54:41.421460: step 2240/4100 (epoch 55/100), loss = 0.121547 (0.038 sec/batch), lr: 0.098477
# Evaluating on test set...
# epoch 55: train_loss = 0.191573, test_loss = 0.340584, test_f1 = 0.9037
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_55.pt
#
# 2026-05-23 01:54:42.629794: step 2260/4100 (epoch 56/100), loss = 0.095444 (0.050 sec/batch), lr: 0.098477
# 2026-05-23 01:54:43.759181: step 2280/4100 (epoch 56/100), loss = 0.169511 (0.046 sec/batch), lr: 0.098477
# Evaluating on test set...
# epoch 56: train_loss = 0.183484, test_loss = 0.348530, test_f1 = 0.8984
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_56.pt
#
# 2026-05-23 01:54:45.225340: step 2300/4100 (epoch 57/100), loss = 0.139890 (0.047 sec/batch), lr: 0.088629
# 2026-05-23 01:54:46.377838: step 2320/4100 (epoch 57/100), loss = 0.082395 (0.045 sec/batch), lr: 0.088629
# Evaluating on test set...
# epoch 57: train_loss = 0.198617, test_loss = 0.329118, test_f1 = 0.8984
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_57.pt
#
# 2026-05-23 01:54:47.629577: step 2340/4100 (epoch 58/100), loss = 0.208050 (0.050 sec/batch), lr: 0.079766
# 2026-05-23 01:54:48.808650: step 2360/4100 (epoch 58/100), loss = 0.218059 (0.051 sec/batch), lr: 0.079766
# Evaluating on test set...
# epoch 58: train_loss = 0.192367, test_loss = 0.344172, test_f1 = 0.8930
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_58.pt
#
# 2026-05-23 01:54:50.242075: step 2380/4100 (epoch 59/100), loss = 0.091096 (0.056 sec/batch), lr: 0.071790
# 2026-05-23 01:54:51.382813: step 2400/4100 (epoch 59/100), loss = 0.200524 (0.053 sec/batch), lr: 0.071790
# Evaluating on test set...
# epoch 59: train_loss = 0.177429, test_loss = 0.344840, test_f1 = 0.9169
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_59.pt
# new best model saved.
#
# 2026-05-23 01:54:52.669929: step 2420/4100 (epoch 60/100), loss = 0.156298 (0.042 sec/batch), lr: 0.071790
# 2026-05-23 01:54:53.815900: step 2440/4100 (epoch 60/100), loss = 0.245823 (0.046 sec/batch), lr: 0.071790
# 2026-05-23 01:54:54.904553: step 2460/4100 (epoch 60/100), loss = 0.200397 (0.029 sec/batch), lr: 0.071790
# Evaluating on test set...
# epoch 60: train_loss = 0.179950, test_loss = 0.355370, test_f1 = 0.8989
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_60.pt
#
# 2026-05-23 01:54:56.364551: step 2480/4100 (epoch 61/100), loss = 0.085951 (0.058 sec/batch), lr: 0.064611
# 2026-05-23 01:54:57.519797: step 2500/4100 (epoch 61/100), loss = 0.267428 (0.053 sec/batch), lr: 0.064611
# Evaluating on test set...
# epoch 61: train_loss = 0.186945, test_loss = 0.336599, test_f1 = 0.8930
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_61.pt
#
# 2026-05-23 01:54:58.746288: step 2520/4100 (epoch 62/100), loss = 0.177539 (0.058 sec/batch), lr: 0.058150
# 2026-05-23 01:54:59.912834: step 2540/4100 (epoch 62/100), loss = 0.112961 (0.059 sec/batch), lr: 0.058150
# Evaluating on test set...
# epoch 62: train_loss = 0.183537, test_loss = 0.332825, test_f1 = 0.9062
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_62.pt
#
# 2026-05-23 01:55:01.394150: step 2560/4100 (epoch 63/100), loss = 0.154080 (0.051 sec/batch), lr: 0.058150
# 2026-05-23 01:55:02.520217: step 2580/4100 (epoch 63/100), loss = 0.151255 (0.045 sec/batch), lr: 0.058150
# Evaluating on test set...
# epoch 63: train_loss = 0.174188, test_loss = 0.334329, test_f1 = 0.9008
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_63.pt
#
# 2026-05-23 01:55:03.795152: step 2600/4100 (epoch 64/100), loss = 0.120226 (0.052 sec/batch), lr: 0.052335
# 2026-05-23 01:55:04.921282: step 2620/4100 (epoch 64/100), loss = 0.202240 (0.070 sec/batch), lr: 0.052335
# Evaluating on test set...
# epoch 64: train_loss = 0.169454, test_loss = 0.339975, test_f1 = 0.9008
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_64.pt
#
# 2026-05-23 01:55:06.133138: step 2640/4100 (epoch 65/100), loss = 0.180056 (0.037 sec/batch), lr: 0.047101
# 2026-05-23 01:55:07.243091: step 2660/4100 (epoch 65/100), loss = 0.290371 (0.036 sec/batch), lr: 0.047101
# Evaluating on test set...
# epoch 65: train_loss = 0.177163, test_loss = 0.337807, test_f1 = 0.9062
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_65.pt
#
# 2026-05-23 01:55:08.155670: step 2680/4100 (epoch 66/100), loss = 0.061392 (0.031 sec/batch), lr: 0.047101
# 2026-05-23 01:55:08.929505: step 2700/4100 (epoch 66/100), loss = 0.224349 (0.032 sec/batch), lr: 0.047101
# Evaluating on test set...
# epoch 66: train_loss = 0.172065, test_loss = 0.336152, test_f1 = 0.9062
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_66.pt
#
# 2026-05-23 01:55:09.813381: step 2720/4100 (epoch 67/100), loss = 0.111284 (0.040 sec/batch), lr: 0.042391
# 2026-05-23 01:55:10.733025: step 2740/4100 (epoch 67/100), loss = 0.275295 (0.033 sec/batch), lr: 0.042391
# Evaluating on test set...
# epoch 67: train_loss = 0.180371, test_loss = 0.334635, test_f1 = 0.9062
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_67.pt
#
# 2026-05-23 01:55:11.655930: step 2760/4100 (epoch 68/100), loss = 0.228574 (0.042 sec/batch), lr: 0.038152
# 2026-05-23 01:55:12.393130: step 2780/4100 (epoch 68/100), loss = 0.202121 (0.034 sec/batch), lr: 0.038152
# Evaluating on test set...
# epoch 68: train_loss = 0.178333, test_loss = 0.331836, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_68.pt
#
# 2026-05-23 01:55:13.257351: step 2800/4100 (epoch 69/100), loss = 0.154289 (0.031 sec/batch), lr: 0.034337
# 2026-05-23 01:55:14.023397: step 2820/4100 (epoch 69/100), loss = 0.143418 (0.030 sec/batch), lr: 0.034337
# Evaluating on test set...
# epoch 69: train_loss = 0.181385, test_loss = 0.344234, test_f1 = 0.9091
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_69.pt
#
# 2026-05-23 01:55:15.055672: step 2840/4100 (epoch 70/100), loss = 0.065036 (0.042 sec/batch), lr: 0.034337
# 2026-05-23 01:55:15.829323: step 2860/4100 (epoch 70/100), loss = 0.161678 (0.030 sec/batch), lr: 0.034337
# Evaluating on test set...
# epoch 70: train_loss = 0.164849, test_loss = 0.333114, test_f1 = 0.8930
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_70.pt
#
# 2026-05-23 01:55:16.715517: step 2880/4100 (epoch 71/100), loss = 0.266364 (0.036 sec/batch), lr: 0.030903
# 2026-05-23 01:55:17.485194: step 2900/4100 (epoch 71/100), loss = 0.246633 (0.027 sec/batch), lr: 0.030903
# Evaluating on test set...
# epoch 71: train_loss = 0.175826, test_loss = 0.340964, test_f1 = 0.9062
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_71.pt
#
# 2026-05-23 01:55:18.646111: step 2920/4100 (epoch 72/100), loss = 0.196716 (0.051 sec/batch), lr: 0.030903
# 2026-05-23 01:55:19.600105: step 2940/4100 (epoch 72/100), loss = 0.136647 (0.035 sec/batch), lr: 0.030903
# Evaluating on test set...
# epoch 72: train_loss = 0.175733, test_loss = 0.334707, test_f1 = 0.9062
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_72.pt
#
# 2026-05-23 01:55:20.542994: step 2960/4100 (epoch 73/100), loss = 0.211525 (0.045 sec/batch), lr: 0.027813
# 2026-05-23 01:55:21.721118: step 2980/4100 (epoch 73/100), loss = 0.218200 (0.069 sec/batch), lr: 0.027813
# Evaluating on test set...
# epoch 73: train_loss = 0.163401, test_loss = 0.334920, test_f1 = 0.9008
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_73.pt
#
# 2026-05-23 01:55:22.780429: step 3000/4100 (epoch 74/100), loss = 0.329139 (0.054 sec/batch), lr: 0.025032
# 2026-05-23 01:55:24.013897: step 3020/4100 (epoch 74/100), loss = 0.099647 (0.051 sec/batch), lr: 0.025032
# Evaluating on test set...
# epoch 74: train_loss = 0.169232, test_loss = 0.337842, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_74.pt
#
# 2026-05-23 01:55:25.216948: step 3040/4100 (epoch 75/100), loss = 0.267878 (0.044 sec/batch), lr: 0.022528
# 2026-05-23 01:55:26.218021: step 3060/4100 (epoch 75/100), loss = 0.079476 (0.040 sec/batch), lr: 0.022528
# Evaluating on test set...
# epoch 75: train_loss = 0.170943, test_loss = 0.337768, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_75.pt
#
# 2026-05-23 01:55:27.434350: step 3080/4100 (epoch 76/100), loss = 0.048018 (0.052 sec/batch), lr: 0.020276
# 2026-05-23 01:55:28.565811: step 3100/4100 (epoch 76/100), loss = 0.164379 (0.042 sec/batch), lr: 0.020276
# Evaluating on test set...
# epoch 76: train_loss = 0.182795, test_loss = 0.332222, test_f1 = 0.9008
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_76.pt
#
# 2026-05-23 01:55:29.981479: step 3120/4100 (epoch 77/100), loss = 0.280927 (0.044 sec/batch), lr: 0.020276
# 2026-05-23 01:55:31.097880: step 3140/4100 (epoch 77/100), loss = 0.066529 (0.049 sec/batch), lr: 0.020276
# Evaluating on test set...
# epoch 77: train_loss = 0.161260, test_loss = 0.340409, test_f1 = 0.9008
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_77.pt
#
# 2026-05-23 01:55:32.361474: step 3160/4100 (epoch 78/100), loss = 0.296854 (0.065 sec/batch), lr: 0.018248
# 2026-05-23 01:55:33.534865: step 3180/4100 (epoch 78/100), loss = 0.222455 (0.042 sec/batch), lr: 0.018248
# Evaluating on test set...
# epoch 78: train_loss = 0.169570, test_loss = 0.340208, test_f1 = 0.9008
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_78.pt
#
# 2026-05-23 01:55:34.744828: step 3200/4100 (epoch 79/100), loss = 0.057186 (0.042 sec/batch), lr: 0.016423
# 2026-05-23 01:55:36.108224: step 3220/4100 (epoch 79/100), loss = 0.194325 (0.046 sec/batch), lr: 0.016423
# Evaluating on test set...
# epoch 79: train_loss = 0.164491, test_loss = 0.336323, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_79.pt
#
# 2026-05-23 01:55:37.420046: step 3240/4100 (epoch 80/100), loss = 0.158349 (0.045 sec/batch), lr: 0.014781
# 2026-05-23 01:55:38.627155: step 3260/4100 (epoch 80/100), loss = 0.236784 (0.046 sec/batch), lr: 0.014781
# 2026-05-23 01:55:39.727901: step 3280/4100 (epoch 80/100), loss = 0.077147 (0.035 sec/batch), lr: 0.014781
# Evaluating on test set...
# epoch 80: train_loss = 0.157812, test_loss = 0.335123, test_f1 = 0.9008
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_80.pt
#
# 2026-05-23 01:55:41.063134: step 3300/4100 (epoch 81/100), loss = 0.080361 (0.050 sec/batch), lr: 0.014781
# 2026-05-23 01:55:42.358830: step 3320/4100 (epoch 81/100), loss = 0.293454 (0.042 sec/batch), lr: 0.014781
# Evaluating on test set...
# epoch 81: train_loss = 0.166255, test_loss = 0.335361, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_81.pt
#
# 2026-05-23 01:55:43.602948: step 3340/4100 (epoch 82/100), loss = 0.226156 (0.049 sec/batch), lr: 0.013303
# 2026-05-23 01:55:44.706772: step 3360/4100 (epoch 82/100), loss = 0.189348 (0.056 sec/batch), lr: 0.013303
# Evaluating on test set...
# epoch 82: train_loss = 0.166189, test_loss = 0.334303, test_f1 = 0.9008
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_82.pt
#
# 2026-05-23 01:55:45.992885: step 3380/4100 (epoch 83/100), loss = 0.114471 (0.048 sec/batch), lr: 0.013303
# 2026-05-23 01:55:47.311631: step 3400/4100 (epoch 83/100), loss = 0.118825 (0.045 sec/batch), lr: 0.013303
# Evaluating on test set...
# epoch 83: train_loss = 0.171914, test_loss = 0.336319, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_83.pt
#
# 2026-05-23 01:55:48.594752: step 3420/4100 (epoch 84/100), loss = 0.222309 (0.047 sec/batch), lr: 0.011973
# 2026-05-23 01:55:49.763040: step 3440/4100 (epoch 84/100), loss = 0.112031 (0.062 sec/batch), lr: 0.011973
# Evaluating on test set...
# epoch 84: train_loss = 0.169280, test_loss = 0.337125, test_f1 = 0.9008
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_84.pt
#
# 2026-05-23 01:55:51.007577: step 3460/4100 (epoch 85/100), loss = 0.219420 (0.052 sec/batch), lr: 0.011973
# 2026-05-23 01:55:51.962856: step 3480/4100 (epoch 85/100), loss = 0.287762 (0.038 sec/batch), lr: 0.011973
# Evaluating on test set...
# epoch 85: train_loss = 0.165544, test_loss = 0.336241, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_85.pt
#
# 2026-05-23 01:55:53.002675: step 3500/4100 (epoch 86/100), loss = 0.073570 (0.025 sec/batch), lr: 0.010775
# 2026-05-23 01:55:53.780291: step 3520/4100 (epoch 86/100), loss = 0.121962 (0.034 sec/batch), lr: 0.010775
# Evaluating on test set...
# epoch 86: train_loss = 0.153376, test_loss = 0.336360, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_86.pt
#
# 2026-05-23 01:55:54.944401: step 3540/4100 (epoch 87/100), loss = 0.115504 (0.062 sec/batch), lr: 0.009698
# 2026-05-23 01:55:55.958076: step 3560/4100 (epoch 87/100), loss = 0.338018 (0.049 sec/batch), lr: 0.009698
# Evaluating on test set...
# epoch 87: train_loss = 0.166733, test_loss = 0.336272, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_87.pt
#
# 2026-05-23 01:55:57.445159: step 3580/4100 (epoch 88/100), loss = 0.231273 (0.066 sec/batch), lr: 0.008728
# 2026-05-23 01:55:58.572636: step 3600/4100 (epoch 88/100), loss = 0.121548 (0.045 sec/batch), lr: 0.008728
# Evaluating on test set...
# epoch 88: train_loss = 0.174716, test_loss = 0.334611, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_88.pt
#
# 2026-05-23 01:55:59.802830: step 3620/4100 (epoch 89/100), loss = 0.119374 (0.040 sec/batch), lr: 0.007855
# 2026-05-23 01:56:00.999881: step 3640/4100 (epoch 89/100), loss = 0.095223 (0.046 sec/batch), lr: 0.007855
# Evaluating on test set...
# epoch 89: train_loss = 0.160425, test_loss = 0.335036, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_89.pt
#
# 2026-05-23 01:56:02.329811: step 3660/4100 (epoch 90/100), loss = 0.121541 (0.063 sec/batch), lr: 0.007070
# 2026-05-23 01:56:03.646586: step 3680/4100 (epoch 90/100), loss = 0.120076 (0.041 sec/batch), lr: 0.007070
# Evaluating on test set...
# epoch 90: train_loss = 0.162782, test_loss = 0.333881, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_90.pt
#
# 2026-05-23 01:56:04.967551: step 3700/4100 (epoch 91/100), loss = 0.205019 (0.052 sec/batch), lr: 0.006363
# 2026-05-23 01:56:06.112970: step 3720/4100 (epoch 91/100), loss = 0.231675 (0.044 sec/batch), lr: 0.006363
# Evaluating on test set...
# epoch 91: train_loss = 0.163903, test_loss = 0.332709, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_91.pt
#
# 2026-05-23 01:56:07.402646: step 3740/4100 (epoch 92/100), loss = 0.312091 (0.060 sec/batch), lr: 0.005726
# 2026-05-23 01:56:08.634681: step 3760/4100 (epoch 92/100), loss = 0.169190 (0.051 sec/batch), lr: 0.005726
# Evaluating on test set...
# epoch 92: train_loss = 0.168057, test_loss = 0.333178, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_92.pt
#
# 2026-05-23 01:56:10.072495: step 3780/4100 (epoch 93/100), loss = 0.200555 (0.057 sec/batch), lr: 0.005154
# 2026-05-23 01:56:11.222656: step 3800/4100 (epoch 93/100), loss = 0.262098 (0.072 sec/batch), lr: 0.005154
# Evaluating on test set...
# epoch 93: train_loss = 0.165264, test_loss = 0.334829, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_93.pt
#
# 2026-05-23 01:56:12.529191: step 3820/4100 (epoch 94/100), loss = 0.225999 (0.069 sec/batch), lr: 0.004638
# 2026-05-23 01:56:13.603961: step 3840/4100 (epoch 94/100), loss = 0.123584 (0.044 sec/batch), lr: 0.004638
# Evaluating on test set...
# epoch 94: train_loss = 0.161882, test_loss = 0.334582, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_94.pt
#
# 2026-05-23 01:56:14.936499: step 3860/4100 (epoch 95/100), loss = 0.344809 (0.041 sec/batch), lr: 0.004175
# 2026-05-23 01:56:15.986952: step 3880/4100 (epoch 95/100), loss = 0.096353 (0.043 sec/batch), lr: 0.004175
# Evaluating on test set...
# epoch 95: train_loss = 0.169850, test_loss = 0.334379, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_95.pt
#
# 2026-05-23 01:56:17.281645: step 3900/4100 (epoch 96/100), loss = 0.087182 (0.052 sec/batch), lr: 0.003757
# 2026-05-23 01:56:18.217624: step 3920/4100 (epoch 96/100), loss = 0.147177 (0.035 sec/batch), lr: 0.003757
# Evaluating on test set...
# epoch 96: train_loss = 0.173097, test_loss = 0.333139, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_96.pt
#
# 2026-05-23 01:56:19.282971: step 3940/4100 (epoch 97/100), loss = 0.111320 (0.036 sec/batch), lr: 0.003381
# 2026-05-23 01:56:20.474325: step 3960/4100 (epoch 97/100), loss = 0.085435 (0.045 sec/batch), lr: 0.003381
# Evaluating on test set...
# epoch 97: train_loss = 0.158271, test_loss = 0.333113, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_97.pt
#
# 2026-05-23 01:56:21.799883: step 3980/4100 (epoch 98/100), loss = 0.194584 (0.065 sec/batch), lr: 0.003043
# 2026-05-23 01:56:22.948136: step 4000/4100 (epoch 98/100), loss = 0.254249 (0.044 sec/batch), lr: 0.003043
# Evaluating on test set...
# epoch 98: train_loss = 0.179351, test_loss = 0.331955, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_98.pt
#
# 2026-05-23 01:56:24.185890: step 4020/4100 (epoch 99/100), loss = 0.040766 (0.046 sec/batch), lr: 0.002739
# 2026-05-23 01:56:25.355613: step 4040/4100 (epoch 99/100), loss = 0.140242 (0.045 sec/batch), lr: 0.002739
# Evaluating on test set...
# epoch 99: train_loss = 0.167863, test_loss = 0.331411, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_99.pt
#
# 2026-05-23 01:56:26.834375: step 4060/4100 (epoch 100/100), loss = 0.196311 (0.044 sec/batch), lr: 0.002465
# 2026-05-23 01:56:27.937968: step 4080/4100 (epoch 100/100), loss = 0.190295 (0.045 sec/batch), lr: 0.002465
# 2026-05-23 01:56:29.027734: step 4100/4100 (epoch 100/100), loss = 0.127935 (0.033 sec/batch), lr: 0.002465
# Evaluating on test set...
# epoch 100: train_loss = 0.175977, test_loss = 0.331430, test_f1 = 0.8954
# model saved to saved_models/cgcn_cnc/01/checkpoint_epoch_100.pt
#
# Training ended with 100 epochs.
#
# Running final evaluation with shared evaluator...
# Best predictions saved to results/cgcn/cnc\predictions.txt
#
# ============================================================
#   EVALUATION: cgcn  |  dataset: cnc
# ============================================================
#
#   *** PRIMARY METRIC ***
#   Macro F1 (Cause-Effect classes only): 0.8619  (86.19%)
#
#   Per-class results:
#   Label                            P       R      F1   Support
#   --------------------------------------------------------
#   Cause-Effect(e1,e2)         0.7647  0.7879  0.7761        33
#   Cause-Effect(e2,e1)         0.9416  0.9539  0.9477       152
#   Other                       0.9032  0.8235  0.8615        34
#
#   Overall:
#     Macro F1 (all 3 classes): 0.8618
#     Micro F1:                 0.9087
#     Accuracy:                 0.9087
# ============================================================
#
#
# Results saved to: results/cgcn/cnc
#   report.txt
#   metrics.json
#   confusion_matrix.png
# Evaluation complete. Results saved to results/cgcn/cnc
# c:\Users\rusne\OneDrive - TU Eindhoven\bep-causal-relation-extraction\venv\Lib\site-packages\torch\nn\modules\rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn(

# %% [markdown]
# ## 6. View results

# %%
import json
with open('results/cgcn/cnc/metrics.json') as f:
    metrics = json.load(f)
print(json.dumps(metrics, indent=2))
# Out:
# {
#   "model": "cgcn",
#   "dataset": "cnc",
#   "primary": {
#     "macro_f1_causal_only": 0.8619
#   },
#   "per_class": {
#     "Cause-Effect(e1,e2)": {
#       "precision": 0.7647,
#       "recall": 0.7879,
#       "f1": 0.7761,
#       "support": 33
#     },
#     "Cause-Effect(e2,e1)": {
#       "precision": 0.9416,
#       "recall": 0.9539,
#       "f1": 0.9477,
#       "support": 152
#     },
#     "Other": {
#       "precision": 0.9032,
#       "recall": 0.8235,
#       "f1": 0.8615,
#       "support": 34
#     }
#   },
#   "overall": {
#     "macro_f1_all3": 0.8618,
#     "micro_f1": 0.9087,
#     "accuracy": 0.9087
#   },
#   "confusion_matrix": [
#     [
#       26,
#       7,
#       0
#     ],
#     [
#       4,
#       145,
#       3
#     ],
#     [
#       4,
#       2,
#       28
#     ]
#   ]
# }

# %%
from IPython.display import Image
Image('results/cgcn/cnc/confusion_matrix.png')
