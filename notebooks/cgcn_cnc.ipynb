# %% [markdown]
# # C-GCN: Causal Relation Extraction (3-class)
#
# Trains and evaluates C-GCN on Causal News Corpus, adapted for 3-class causal relation extraction.

# %% [markdown]
# ## 1. Set working directory to repo root

# %%
import os
if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('..')
print("Working directory:", os.getcwd())
# Out:
# Working directory: c:\Users\rusne\OneDrive - TU Eindhoven\bep-causal-relation-extraction

# %% [markdown]
# ## 2. Check GPU

# %%
import torch
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# GPU: NVIDIA RTX 1000 Ada Generation Laptop GPU

# %% [markdown]
# ## 3. Download GloVe embeddings
#
# Downloads `glove.840B.300d.txt` to `data/glove/`. Skip this if you already have it.

# %%
import os, urllib.request, zipfile

glove_dir = 'data/glove'
glove_txt = os.path.join(glove_dir, 'glove.840B.300d.txt')
glove_zip = os.path.join(glove_dir, 'glove.840B.300d.zip')

if os.path.exists(glove_txt):
    print("GloVe already downloaded, skipping.")
else:
    os.makedirs(glove_dir, exist_ok=True)
    url = 'https://huggingface.co/stanfordnlp/glove/resolve/main/glove.840B.300d.zip'
    print(f"Downloading GloVe (~2 GB), this will take a few minutes...")
    urllib.request.urlretrieve(url, glove_zip)
    print("Unzipping...")
    with zipfile.ZipFile(glove_zip, 'r') as z:
        z.extractall(glove_dir)
    os.remove(glove_zip)
    print("Done:", glove_txt)
# Out:
# GloVe already downloaded, skipping.

# %% [markdown]
# ## 4. Build vocabulary and embedding matrix (run once)
#
# Reads `data/CausalNewsCorpus/cgcn/train.json` + `test.json`, looks up GloVe vectors, saves `vocab.pkl` + `embedding.npy`.

# %%
import os
os.makedirs('data/CausalNewsCorpus/cgcn/vocab', exist_ok=True)

# !python src/cgcn/prepare_vocab.py data/CausalNewsCorpus/cgcn data/CausalNewsCorpus/cgcn/vocab --glove_dir data/glove --wv_file glove.840B.300d.txt
# Out:
# loading files...
# 28669 tokens from 2023 examples loaded from data/CausalNewsCorpus/cgcn/train.json.
# 3113 tokens from 219 examples loaded from data/CausalNewsCorpus/cgcn/test.json.
# loading glove...
# 2195893 words loaded from glove.
# building vocab...
# vocab built with 5377/5669 words.
# calculating oov...
# train oov: 354/28669 (1.23%)
# test oov: 421/3113 (13.52%)
# building embeddings...
# embedding size: 5377 x 300
# dumping to files...
# all done.

# %% [markdown]
# ## 5. Train C-GCN
#
# | Run | Seed | Results location |
# |-----|------|------------------|
# | 1   | 1234 | `results/cgcn/cnc/` |
# | 2   | 1    | `results/cgcn/cnc/seed_1/` |
# | 3   | 2    | `results/cgcn/cnc/seed_2/` |
# | 4   | 3    | `results/cgcn/cnc/seed_3/` |
# | 5   | 4    | `results/cgcn/cnc/seed_4/` |

# %%
# Run 1 of 5 — seed 1234 
os.makedirs('results/cgcn/cnc', exist_ok=True)
os.makedirs('saved_models/cgcn_cnc', exist_ok=True)
# !python src/cgcn/train.py --data_dir data/CausalNewsCorpus/cgcn --vocab_dir data/CausalNewsCorpus/cgcn/vocab --eval_dir results/cgcn/cnc --save_dir saved_models/cgcn_cnc --id 01 --prune_k 1 --lr 1.0 --optim sgd --num_epoch 100 --batch_size 50 --seed 1234
# Out:
# ^C
# Vocab size 5377 loaded from file
# Loading data from data/CausalNewsCorpus/cgcn with batch size 50...
# 41 batches created for data/CausalNewsCorpus/cgcn/train.json
# 5 batches created for data/CausalNewsCorpus/cgcn/test.json
# Config saved to file saved_models/cgcn_cnc/01/config.json
# Overwriting old vocab file at saved_models/cgcn_cnc/01/vocab.pkl
#
# Running with the following configs:
# 	data_dir : data/CausalNewsCorpus/cgcn
# 	vocab_dir : data/CausalNewsCorpus/cgcn/vocab
# 	eval_dir : results/cgcn/cnc
# 	emb_dim : 300
# 	ner_dim : 30
# 	pos_dim : 30
# 	hidden_dim : 200
# 	num_layers : 2
# 	input_dropout : 0.5
# 	gcn_dropout : 0.5
# 	word_dropout : 0.04
# 	topn : 10000000000.0
# 	lower : False
# 	prune_k : 1
# 	conv_l2 : 0
# 	pooling : max
# 	pooling_l2 : 0
# 	mlp_layers : 2
# 	no_adj : False
# 	rnn : True
# 	rnn_hidden : 200
# 	rnn_layers : 1
# 	rnn_dropout : 0.5
# 	lr : 1.0
# 	lr_decay : 0.9
# 	decay_epoch : 5
# 	optim : sgd
# 	num_epoch : 100
# 	batch_size : 50
# ...

# %%
# Run 2 of 5 — seed 1
os.makedirs('results/cgcn/cnc/seed_1', exist_ok=True)
os.makedirs('saved_models/cgcn_cnc', exist_ok=True)
# !python src/cgcn/train.py --data_dir data/CausalNewsCorpus/cgcn --vocab_dir data/CausalNewsCorpus/cgcn/vocab --eval_dir results/cgcn/cnc/seed_1 --save_dir saved_models/cgcn_cnc --id 01 --prune_k 1 --lr 1.0 --optim sgd --num_epoch 100 --batch_size 50 --seed 1
# Out:
# Vocab size 5377 loaded from file
# Loading data from data/CausalNewsCorpus/cgcn with batch size 50...
# 41 batches created for data/CausalNewsCorpus/cgcn/train.json
# 5 batches created for data/CausalNewsCorpus/cgcn/test.json
# Config saved to file saved_models/cgcn_cnc/01/config.json
# Overwriting old vocab file at saved_models/cgcn_cnc/01/vocab.pkl
#
# Running with the following configs:
# 	data_dir : data/CausalNewsCorpus/cgcn
# 	vocab_dir : data/CausalNewsCorpus/cgcn/vocab
# 	eval_dir : results/cgcn/cnc/seed_1
# 	emb_dim : 300
# 	ner_dim : 30
# 	pos_dim : 30
# 	hidden_dim : 200
# 	num_layers : 2
# 	input_dropout : 0.5
# 	gcn_dropout : 0.5
# 	word_dropout : 0.04
# 	topn : 10000000000.0
# 	lower : False
# 	prune_k : 1
# 	conv_l2 : 0
# 	pooling : max
# 	pooling_l2 : 0
# 	mlp_layers : 2
# 	no_adj : False
# 	rnn : True
# 	rnn_hidden : 200
# 	rnn_layers : 1
# 	rnn_dropout : 0.5
# 	lr : 1.0
# 	lr_decay : 0.9
# 	decay_epoch : 5
# 	optim : sgd
# 	num_epoch : 100
# 	batch_size : 50
# ...

# %%
# Run 3 of 5 — seed 2
os.makedirs('results/cgcn/cnc/seed_2', exist_ok=True)
os.makedirs('saved_models/cgcn_cnc', exist_ok=True)
# !python src/cgcn/train.py --data_dir data/CausalNewsCorpus/cgcn --vocab_dir data/CausalNewsCorpus/cgcn/vocab --eval_dir results/cgcn/cnc/seed_2 --save_dir saved_models/cgcn_cnc --id 01 --prune_k 1 --lr 1.0 --optim sgd --num_epoch 100 --batch_size 50 --seed 2
# Out:
# Vocab size 5377 loaded from file
# Loading data from data/CausalNewsCorpus/cgcn with batch size 50...
# 41 batches created for data/CausalNewsCorpus/cgcn/train.json
# 5 batches created for data/CausalNewsCorpus/cgcn/test.json
# Config saved to file saved_models/cgcn_cnc/01/config.json
# Overwriting old vocab file at saved_models/cgcn_cnc/01/vocab.pkl
#
# Running with the following configs:
# 	data_dir : data/CausalNewsCorpus/cgcn
# 	vocab_dir : data/CausalNewsCorpus/cgcn/vocab
# 	eval_dir : results/cgcn/cnc/seed_2
# 	emb_dim : 300
# 	ner_dim : 30
# 	pos_dim : 30
# 	hidden_dim : 200
# 	num_layers : 2
# 	input_dropout : 0.5
# 	gcn_dropout : 0.5
# 	word_dropout : 0.04
# 	topn : 10000000000.0
# 	lower : False
# 	prune_k : 1
# 	conv_l2 : 0
# 	pooling : max
# 	pooling_l2 : 0
# 	mlp_layers : 2
# 	no_adj : False
# 	rnn : True
# 	rnn_hidden : 200
# 	rnn_layers : 1
# 	rnn_dropout : 0.5
# 	lr : 1.0
# 	lr_decay : 0.9
# 	decay_epoch : 5
# 	optim : sgd
# 	num_epoch : 100
# 	batch_size : 50
# ...

# %%
# Run 4 of 5 — seed 3
os.makedirs('results/cgcn/cnc/seed_3', exist_ok=True)
os.makedirs('saved_models/cgcn_cnc', exist_ok=True)
# !python src/cgcn/train.py --data_dir data/CausalNewsCorpus/cgcn --vocab_dir data/CausalNewsCorpus/cgcn/vocab --eval_dir results/cgcn/cnc/seed_3 --save_dir saved_models/cgcn_cnc --id 01 --prune_k 1 --lr 1.0 --optim sgd --num_epoch 100 --batch_size 50 --seed 3
# Out:
# Vocab size 5377 loaded from file
# Loading data from data/CausalNewsCorpus/cgcn with batch size 50...
# 41 batches created for data/CausalNewsCorpus/cgcn/train.json
# 5 batches created for data/CausalNewsCorpus/cgcn/test.json
# Config saved to file saved_models/cgcn_cnc/01/config.json
# Overwriting old vocab file at saved_models/cgcn_cnc/01/vocab.pkl
#
# Running with the following configs:
# 	data_dir : data/CausalNewsCorpus/cgcn
# 	vocab_dir : data/CausalNewsCorpus/cgcn/vocab
# 	eval_dir : results/cgcn/cnc/seed_3
# 	emb_dim : 300
# 	ner_dim : 30
# 	pos_dim : 30
# 	hidden_dim : 200
# 	num_layers : 2
# 	input_dropout : 0.5
# 	gcn_dropout : 0.5
# 	word_dropout : 0.04
# 	topn : 10000000000.0
# 	lower : False
# 	prune_k : 1
# 	conv_l2 : 0
# 	pooling : max
# 	pooling_l2 : 0
# 	mlp_layers : 2
# 	no_adj : False
# 	rnn : True
# 	rnn_hidden : 200
# 	rnn_layers : 1
# 	rnn_dropout : 0.5
# 	lr : 1.0
# 	lr_decay : 0.9
# 	decay_epoch : 5
# 	optim : sgd
# 	num_epoch : 100
# 	batch_size : 50
# ...

# %%
# Run 5 of 5 — seed 4
os.makedirs('results/cgcn/cnc/seed_4', exist_ok=True)
os.makedirs('saved_models/cgcn_cnc', exist_ok=True)
# !python src/cgcn/train.py --data_dir data/CausalNewsCorpus/cgcn --vocab_dir data/CausalNewsCorpus/cgcn/vocab --eval_dir results/cgcn/cnc/seed_4 --save_dir saved_models/cgcn_cnc --id 01 --prune_k 1 --lr 1.0 --optim sgd --num_epoch 100 --batch_size 50 --seed 4
# Out:
# Vocab size 5377 loaded from file
# Loading data from data/CausalNewsCorpus/cgcn with batch size 50...
# 41 batches created for data/CausalNewsCorpus/cgcn/train.json
# 5 batches created for data/CausalNewsCorpus/cgcn/test.json
# Config saved to file saved_models/cgcn_cnc/01/config.json
# Overwriting old vocab file at saved_models/cgcn_cnc/01/vocab.pkl
#
# Running with the following configs:
# 	data_dir : data/CausalNewsCorpus/cgcn
# 	vocab_dir : data/CausalNewsCorpus/cgcn/vocab
# 	eval_dir : results/cgcn/cnc/seed_4
# 	emb_dim : 300
# 	ner_dim : 30
# 	pos_dim : 30
# 	hidden_dim : 200
# 	num_layers : 2
# 	input_dropout : 0.5
# 	gcn_dropout : 0.5
# 	word_dropout : 0.04
# 	topn : 10000000000.0
# 	lower : False
# 	prune_k : 1
# 	conv_l2 : 0
# 	pooling : max
# 	pooling_l2 : 0
# 	mlp_layers : 2
# 	no_adj : False
# 	rnn : True
# 	rnn_hidden : 200
# 	rnn_layers : 1
# 	rnn_dropout : 0.5
# 	lr : 1.0
# 	lr_decay : 0.9
# 	decay_epoch : 5
# 	optim : sgd
# 	num_epoch : 100
# 	batch_size : 50
# ...
